# %%
    rea Health Resources File
    rea Health Resources File
# Out:
#   File "<ipython-input-1-331f160efea0>", line 1
#     rea Health Resources File
#              ^
# SyntaxError: invalid syntax

# %%
us_state_to_abbrev = {
"Alabama": "AL",
"Alaska": "AK",
"Arizona": "AZ",
"Arkansas": "AR",
"California": "CA",
"Colorado": "CO",
"Connecticut": "CT",
"Delaware": "DE",
"Florida": "FL",
"Georgia": "GA",
"Hawaii": "HI",
"Idaho": "ID",
"Illinois": "IL",
"Indiana": "IN",
"Iowa": "IA",
"Kansas": "KS",
"Kentucky": "KY",
"Louisiana": "LA",
"Maine": "ME",
"Maryland": "MD",
"Massachusetts": "MA",
"Michigan": "MI",
"Minnesota": "MN",
"Mississippi": "MS",
"Missouri": "MO",
"Montana": "MT",
"Nebraska": "NE",
"Nevada": "NV",
"New Hampshire": "NH",
"New Jersey": "NJ",
"New Mexico": "NM",
"New York": "NY",
"North Carolina": "NC",
"North Dakota": "ND",
"Ohio": "OH",
"Oklahoma": "OK",
"Oregon": "OR",
"Pennsylvania": "PA",
"Rhode Island": "RI",
"South Carolina": "SC",
"South Dakota": "SD",
"Tennessee": "TN",
"Texas": "TX",
"Utah": "UT",
"Vermont": "VT",
"Virginia": "VA",
"Washington": "WA",
"West Virginia": "WV",
"Wisconsin": "WI",
"Wyoming": "WY",
"District of Columbia": "DC"
}

# %%
import pandas as pd
import numpy as np
import geopandas
import matplotlib.colors as colors
import math
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import plotly.express as px

# %%
yr_21 = pd.read_csv("Providers/AHRFDashboard_20-21.csv", skiprows = 2).drop("Source", axis = 1).rename(columns={"State/Territory":"NAME", "M.D., Ophthalmology (County Level File)":"MD_21", "Population, All (County Level File)":"Pop_21", "Rate (per 100,000 population)":"Rate_100k_21"}).loc[0:53, :]
yr_20 = pd.read_csv("Providers/AHRFDashboard_19_20.csv", skiprows = 2).drop("Source", axis = 1).rename(columns={"State/Territory":"NAME", "M.D., Ophthalmology (County Level File)":"MD_20", "Population, All (County Level File)":"Pop_20", "Rate (per 100,000 population)":"Rate_100k_20"}).loc[0:53, :]
yr_19 = pd.read_csv("Providers/AHRFDashboard_18_19.csv", skiprows = 2).drop("Source", axis = 1).rename(columns={"State/Territory":"NAME", "M.D., Ophthalmology (County Level File)":"MD_19", "Population, All (County Level File)":"Pop_19", "Rate (per 100,000 population)":"Rate_100k_19"}).loc[0:53, :]

# %%
def covid_total_pull(condition, month, years, state):
    years_all = [x for x in range(years[0], years[-1]+1)]
    months = ["0"+str(x) for x in range(1,10)] + [str(x) for x in range(10,13)]
    dates = [str(years_all[0])+"-"+months[y]+"-01" for y in range(month-1, 12)]
    if len(years_all) >=2:
        dates += [str(years_all[-1])+"-"+months[y]+"-01" for y in range(0,month)]
    if len(years_all) >2:
        for x in range(years_all[1], years_all[-1]):
            dates += [str(x)+"-"+months[y]+"-01" for y in range(0,12)]
    dates = sorted(dates)
    
    df = pd.read_csv("COVID/"+condition+"_"+state+".csv")
    try:
        df = df.drop("isPartial", axis = 1)
    except:
        return None
    df = df[df["date"].isin(dates)].mean()
    df = pd.DataFrame(df, columns = [state])
    return(df)

# %%
def pull_all_states(condition, month, years):
    all_data = covid_total_pull(condition, month, years, "MA")
    for x in us_state_to_abbrev:
        state = us_state_to_abbrev[x]
        if state != "Massachusetts":
            data_next = covid_total_pull(condition, month, years, state)
            if data_next is not None:
                all_data[state] = data_next[state]
            else:
                all_data[state] = 0
    return all_data

# %%
def all_conditions(month, years):
    kw_list = ["cataract", "diabetic retinopathy", "macular degeneration", "uveitis"]
    all_data = pull_all_states("glaucoma", month, years)
    for x in kw_list:
        all_data = pd.concat([all_data, pull_all_states(x, month, years)])
    return all_data

# %%
state_to_state = all_conditions(10, [2020, 2021]).mean()
state_to_state = pd.DataFrame(state_to_state, columns = ["Interest_21"])
state_to_state["Interest_20"] = all_conditions(10, [2019, 2020]).mean()
state_to_state["Interest_19"] = all_conditions(10, [2018, 2019]).mean()
state_to_state["STUSPS"] = state_to_state.index
state_to_state
# Out:
#     Interest_21  Interest_20  Interest_19 STUSPS
# MA    49.338462    42.646154    44.630769     MA
# AL    27.492308    26.938462    27.830769     AL
# AK    11.876923    11.369231    12.123077     AK
# AZ    41.307692    36.415385    39.769231     AZ
# AR    19.169231    16.061538    17.692308     AR
# CA    57.307692    50.276923    56.630769     CA
# CO    39.046154    35.184615    38.369231     CO
# CT    34.184615    30.615385    34.353846     CT
# DE    12.292308    11.246154    11.276923     DE
# FL    55.123077    50.892308    53.323077     FL
# GA    40.907692    38.015385    38.353846     GA
# HI    25.076923    23.646154    23.584615     HI
# ID    15.153846    13.338462    14.000000     ID
# IL    50.800000    44.153846    47.553846     IL
# IN    32.584615    29.492308    28.076923     IN
# IA    24.246154    21.784615    21.984615     IA
# KS    31.384615    27.138462    31.046154     KS
# KY    34.507692    28.076923    31.400000     KY
# ...

# %%
states = geopandas.read_file('data/usa-states-census-2014.shp')
states = states.drop_duplicates()
states = states.merge(state_to_state, on="STUSPS")
states = states.merge(yr_21, on="NAME")
states = states.merge(yr_20, on="NAME")
states = states.merge(yr_19, on="NAME")
states = states.sort_values(by=['NAME'])
states
# Out:
#    STATEFP   STATENS     AFFGEOID GEOID STUSPS                  NAME LSAD  \
# 41      01  01779775  0400000US01    01     AL               Alabama   00
# 19      04  01779777  0400000US04    04     AZ               Arizona   00
# 20      05  00068085  0400000US05    05     AR              Arkansas   00
# 0       06  01779778  0400000US06    06     CA            California   00
# 21      08  01779779  0400000US08    08     CO              Colorado   00
# 23      09  01779780  0400000US09    09     CT           Connecticut   00
# 39      10  01779781  0400000US10    10     DE              Delaware   00
# 1       11  01702382  0400000US11    11     DC  District of Columbia   00
# 2       12  00294478  0400000US12    12     FL               Florida   00
# 3       13  01705317  0400000US13    13     GA               Georgia   00
# 4       16  01779783  0400000US16    16     ID                 Idaho   00
# 5       17  01779784  0400000US17    17     IL              Illinois   00
# ...

# %%
states["Need_21"] = states["Interest_21"]/states["Rate_100k_21"]
states["Need_20"] = states["Interest_20"]/states["Rate_100k_20"]
states["Need_19"] = states["Interest_19"]/states["Rate_100k_19"]
states['Need_21_Region'] = states.groupby(['region'])['Need_21'].transform('mean')
states['Need_20_Region'] = states.groupby(['region'])['Need_20'].transform('mean')
states['Need_19_Region'] = states.groupby(['region'])['Need_19'].transform('mean')
states['Interest_21_Region'] = states.groupby(['region'])['Interest_21'].transform('mean')
states['Interest_20_Region'] = states.groupby(['region'])['Interest_20'].transform('mean')
states['Interest_19_Region'] = states.groupby(['region'])['Interest_19'].transform('mean')
states['Rate_100k_21_Region'] = states.groupby(['region'])['Rate_100k_21'].transform('mean')
states['Rate_100k_20_Region'] = states.groupby(['region'])['Rate_100k_20'].transform('mean')
states['Rate_100k_19_Region'] = states.groupby(['region'])['Rate_100k_19'].transform('mean')
states.sort_values(by=["Need_21_Region"])
# Out:
#    STATEFP   STATENS     AFFGEOID GEOID STUSPS                  NAME LSAD  \
# 9       24  01714934  0400000US24    24     MD              Maryland   00
# 13      36  01779796  0400000US36    36     NY              New York   00
# 48      34  01779795  0400000US34    34     NJ            New Jersey   00
# 47      33  01779794  0400000US33    33     NH         New Hampshire   00
# 29      25  00606926  0400000US25    25     MA         Massachusetts   00
# 43      42  01779798  0400000US42    42     PA          Pennsylvania   00
# 28      23  01779787  0400000US23    23     ME                 Maine   00
# 44      50  01779802  0400000US50    50     VT               Vermont   00
# 40      44  01219835  0400000US44    44     RI          Rhode Island   00
# 23      09  01779780  0400000US09    09     CT           Connecticut   00
# 1       11  01702382  0400000US11    11     DC  District of Columbia   00
# 39      10  01779781  0400000US10    10     DE              Delaware   00
# ...

# %%
regions = states.dissolve(by='region')
regions
# Out:
#                                                     geometry STATEFP  \
# region
# Midwest    MULTIPOLYGON Z (((-87.80048 42.49192 0.00000, ...      17
# Northeast  MULTIPOLYGON Z (((-76.04621 38.02553 0.00000, ...      09
# Southeast  MULTIPOLYGON Z (((-81.81169 24.56874 0.00000, ...      01
# Southwest  POLYGON Z ((-94.48587 33.63787 0.00000, -94.41...      04
# West       MULTIPOLYGON Z (((-104.05325 41.00141 0.00000,...      06
#
#             STATENS     AFFGEOID GEOID STUSPS         NAME LSAD         ALAND  \
# region
# Midwest    01779784  0400000US17    17     IL     Illinois   00  143794747023
# Northeast  01779780  0400000US09    09     CT  Connecticut   00   12542396439
# Southeast  01779775  0400000US01    01     AL      Alabama   00  131172403111
# Southwest  01779777  0400000US04    04     AZ      Arizona   00  294205282243
# West       01779778  0400000US06    06     CA   California   00  403483823181
#
# ...

# %%
def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    new_cmap = colors.LinearSegmentedColormap.from_list('trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),cmap(np.linspace(minval, maxval, n)))
    return new_cmap

arr = np.linspace(0, 50, 100).reshape((10, 10))
fig, ax = plt.subplots(ncols=2)
cmap = plt.get_cmap('PuBu')
new_cmap = truncate_colormap(cmap, 0.1, 0.9)
ax[0].imshow(arr, interpolation='nearest', cmap=cmap)
ax[1].imshow(arr, interpolation='nearest', cmap=new_cmap)
plt.show()

# %%
# Geo Map by State
fig, ((ax1, ax3), (ax2, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
ax1.axis('off')
ax1.set_title('Need for Ophtho Providers 21', fontdict={'fontsize': '15', 'fontweight' : '3'})
states.plot(column='Need_21',
          cmap=new_cmap,
          linewidth=0.9,
            ax=ax1,
            edgecolor='0',
            legend=True)

#Geo Map by Region
ax2.axis('off')
ax2.set_title('Need for Ophtho Providers 21 by Region', fontdict={'fontsize': '15', 'fontweight' : '3'})
states.plot(column='Need_21_Region',
          cmap=new_cmap,
          linewidth=0.3,
            ax=ax2,
            edgecolor='0',
            legend=True)
regions.boundary.plot(
          linewidth=1,
            ax=ax2,
            edgecolor='0')

#Scatter by State
ax3.set_title('2021 States', fontdict={'fontsize': '15', 'fontweight' : '3'})
ax3.set_xlabel("Ophtho Interest")
ax3.set_ylabel("Provider Rate")
x = states["Interest_21"]
y = states["Rate_100k_21"]

ax3.plot(x,y,"+", 
         ms=10, 
         mec="k",)

z = np.polyfit(x, y, 1)
y_hat = np.poly1d(z)(x)

ax3.plot(x, y_hat, 
         "r--",
         lw=1)
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(y,y_hat):0.3f}$"
ax3.text(6, 13, text,
     fontsize=14, verticalalignment='top')

#Scatter by Region
ax4.set_title('2021 Region', fontdict={'fontsize': '15', 'fontweight' : '3'})
ax4.set_xlabel("Ophtho Interest")
ax4.set_ylabel("Provider Rate")
x = states["Interest_21_Region"]
y = states["Rate_100k_21_Region"]

ax4.plot(x,y,"+", 
         ms=10, 
         mec="k",)

z = np.polyfit(x, y, 1)
y_hat = np.poly1d(z)(x)

ax4.plot(x, y_hat, 
         "r--",
         lw=1)
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(y,y_hat):0.3f}$"
ax4.text(29.5, 7.3, text,
     fontsize=14, verticalalignment='top')


fig.savefig('Figures/2021.png')

# %%
# Geo Map by State
fig, ((ax1, ax3), (ax2, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
ax1.axis('off')
ax1.set_title('Need for Ophtho Providers 20', fontdict={'fontsize': '15', 'fontweight' : '3'})
states.plot(column='Need_20',
          cmap=new_cmap,
          linewidth=0.9,
            ax=ax1,
            edgecolor='0',
            legend=True)

#Geo Map by Region
ax2.axis('off')
ax2.set_title('Need for Ophtho Providers 20 by Region', fontdict={'fontsize': '15', 'fontweight' : '3'})
states.plot(column='Need_20_Region',
          cmap=new_cmap,
          linewidth=0.3,
            ax=ax2,
            edgecolor='0',
            legend=True)
regions.boundary.plot(
          linewidth=1,
            ax=ax2,
            edgecolor='0')

#Scatter by State
ax3.set_title('2020 States', fontdict={'fontsize': '15', 'fontweight' : '3'})
ax3.set_xlabel("Ophtho Interest")
ax3.set_ylabel("Provider Rate")
x = states["Interest_20"]
y = states["Rate_100k_20"]

ax3.plot(x,y,"+", 
         ms=10, 
         mec="k",)

z = np.polyfit(x, y, 1)
y_hat = np.poly1d(z)(x)

ax3.plot(x, y_hat, 
         "r--",
         lw=1)
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(y,y_hat):0.3f}$"
ax3.text(6, 13, text,
     fontsize=14, verticalalignment='top')

#Scatter by Region
ax4.set_title('2020 Region', fontdict={'fontsize': '15', 'fontweight' : '3'})
ax4.set_xlabel("Ophtho Interest")
ax4.set_ylabel("Provider Rate")
x = states["Interest_20_Region"]
y = states["Rate_100k_20_Region"]

ax4.plot(x,y,"+", 
         ms=10, 
         mec="k",)

z = np.polyfit(x, y, 1)
y_hat = np.poly1d(z)(x)

ax4.plot(x, y_hat, 
         "r--",
         lw=1)
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(y,y_hat):0.3f}$"
ax4.text(27.5, 7.3, text,
     fontsize=14, verticalalignment='top')

fig.savefig('Figures/2020.png')

# %%
# Geo Map by State
fig, ((ax1, ax3), (ax2, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
ax1.axis('off')
ax1.set_title('Need for Ophtho Providers 19', fontdict={'fontsize': '15', 'fontweight' : '3'})
states.plot(column='Need_19',
          cmap=new_cmap,
          linewidth=0.9,
            ax=ax1,
            edgecolor='0',
            legend=True)

#Geo Map by Region
ax2.axis('off')
ax2.set_title('Need for Ophtho Providers 19 by Region', fontdict={'fontsize': '15', 'fontweight' : '3'})
states.plot(column='Need_19_Region',
          cmap=new_cmap,
          linewidth=0.3,
            ax=ax2,
            edgecolor='0',
            legend=True)
regions.boundary.plot(
          linewidth=1,
            ax=ax2,
            edgecolor='0')

#Scatter by State
ax3.set_title('2019 States', fontdict={'fontsize': '15', 'fontweight' : '3'})
ax3.set_xlabel("Ophtho Interest")
ax3.set_ylabel("Provider Rate")
x = states["Interest_19"]
y = states["Rate_100k_19"]

ax3.plot(x,y,"+", 
         ms=10, 
         mec="k",)

z = np.polyfit(x, y, 1)
y_hat = np.poly1d(z)(x)

ax3.plot(x, y_hat, 
         "r--",
         lw=1)
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(y,y_hat):0.3f}$"
ax3.text(6, 13, text,
     fontsize=14, verticalalignment='top')

#Scatter by Region
ax4.set_title('2019 Region', fontdict={'fontsize': '15', 'fontweight' : '3'})
ax4.set_xlabel("Ophtho Interest")
ax4.set_ylabel("Provider Rate")
x = states["Interest_19_Region"]
y = states["Rate_100k_19_Region"]

ax4.plot(x,y,"+", 
         ms=10, 
         mec="k",)

z = np.polyfit(x, y, 1)
y_hat = np.poly1d(z)(x)

ax4.plot(x, y_hat, 
         "r--",
         lw=1)
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(y,y_hat):0.3f}$"
ax4.text(29.2, 7.3, text,
     fontsize=14, verticalalignment='top')

fig.savefig('Figures/2019.png')

# %%
from plotly.subplots import make_subplots

# %%
fig = px.choropleth(states, geojson=states.geometry, 
                    locations=states.index, color="Need_19",
                    height=500,
                   color_continuous_scale="Viridis")
fig.update_geos(fitbounds="locations", visible=False)
fig.update_layout(
    title_text='Map'
)
fig.update(layout = dict(title=dict(x=0.5)))
fig.update_layout(
    margin={"r":0,"t":30,"l":10,"b":10},
    coloraxis_colorbar={
        'title':'Sum'})
fig.show()
# Out:
# <div>                            <div id="35b39364-0163-4208-8ca6-b56a09a08e26" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35b39364-0163-4208-8ca6-b56a09a08e26")) {                    Plotly.newPlot(                        "35b39364-0163-4208-8ca6-b56a09a08e26",                        [{"coloraxis": "coloraxis", "geo": "geo", "geojson": {"bbox": [-124.72583900000001, 24.498130999999997, -66.949895, 49.384358], "features": [{"bbox": [-88.46866899999999, 30.228313999999997, -84.891841, 35.008027999999996], "geometry": {"coordinates": [[[-88.4686624840513, 31.893855711615597, 0.0], [-88.46866, 31.933173, 0.0], [-88.45338776310929, 32.053049205419704, 0.0], [-88.4311453634628, 32.227636234688894, 0.0], [-88.42827799999999, 32.250143, 0.0], [-88.421
# ...
